# %% [markdown]
# <a href="https://colab.research.google.com/github/birusolankar/Pandas/blob/main/Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Creating a DataFrame

# %%
# using read_csv
ipl = pd.read_csv("/content/ipl-matches.csv")

# %%
movies = pd.read_csv("/content/movies.csv")

# %%
# using lists
student_data = [
    [100,120,10],
    [95,100,8],
    [85,95,5],
    [98,130,8],
    [75,125,8.5]
]

students = pd.DataFrame(student_data, columns=['marks','iq','lpa'])
students
# Out:
#    marks   iq   lpa
# 0    100  120  10.0
# 1     95  100   8.0
# 2     85   95   5.0
# 3     98  130   8.0
# 4     75  125   8.5

# %%
# using dictionary
students_data = {
    'name':['Biru', 'Anuj', 'Shubham', 'Miheer', 'Vipul', 'Ragini', 'Manali'],
    'marks':[100,85,95,56,78,85,89],
    'iq':[100,120,63,125,78,110,111],
    'lpa':[8,9,4,5,7.8,6,7.5]

}

students = pd.DataFrame(students_data)
students.set_index('name', inplace = True)

# %%
students
# Out:
#          marks   iq  lpa
# name
# Biru       100  100  8.0
# Anuj        85  120  9.0
# Shubham     95   63  4.0
# Miheer      56  125  5.0
# Vipul       78   78  7.8
# Ragini      85  110  6.0
# Manali      89  111  7.5

# %%
# shape
print(ipl.shape)
print(movies.shape)
print(students.shape)
# Out:
# (950, 20)
# (1629, 18)
# (7, 3)

# %%
# dtypes ---> gives the details of the datatype of each column
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
students.dtypes
# Out:
# marks      int64
# iq         int64
# lpa      float64
# dtype: object

# %%
# index
print(ipl.index)
print(movies.index)
print(students.index)
# Out:
# RangeIndex(start=0, stop=950, step=1)
# RangeIndex(start=0, stop=1629, step=1)
# Index(['Biru', 'Anuj', 'Shubham', 'Miheer', 'Vipul', 'Ragini', 'Manali'], dtype='object', name='name')

# %%
# columns ---> gives the name of the columns of the dataset
print(ipl.columns)
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
print(movies.columns)
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
print(students.columns)
# Out:
# Index(['marks', 'iq', 'lpa'], dtype='object')

# %%
# values ---> gives the values of the dataset
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tail
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# sample
ipl.sample(2)
# Out:
#          ID     City        Date Season MatchNumber                Team1  \
# 702  501271  Chennai  2011-05-28   2011       Final  Chennai Super Kings
# 619  598006   Mumbai  2013-04-09   2013          10       Mumbai Indians
#
#                            Team2                            Venue  \
# 702  Royal Challengers Bangalore  MA Chidambaram Stadium, Chepauk
# 619             Delhi Daredevils                 Wankhede Stadium
#
#               TossWinner TossDecision SuperOver          WinningTeam WonBy  \
# 702  Chennai Super Kings          bat         N  Chennai Super Kings  Runs
# 619       Mumbai Indians          bat         N       Mumbai Indians  Runs
#
#      Margin method Player_of_Match  \
# 702    58.0    NaN         M Vijay
# 619    44.0    NaN      KD Karthik
#
#                                           Team1Players  \
# 702  ['MEK Hussey', 'M Vijay', 'MS Dhoni', 'SK Rain...
# 619  ['RT Ponting', 'SR Tendulkar', 'KD Karthik', '...
#
# ...

# %%
# info
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
# describe --->statical summary of the data
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
# isnull
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated
ipl['TossWinner'].duplicated().sum()
# Out:
# 932

# %%
ipl['ID'].duplicated().sum()
# Out:
# 0

# %%
# rename
students.rename(columns={'marks':'percentage','lpa':'CTC'}, inplace=True)

# %%
students
# Out:
#          percentage   iq  CTC
# name
# Biru            100  100  8.0
# Anuj             85  120  9.0
# Shubham          95   63  4.0
# Miheer           56  125  5.0
# Vipul            78   78  7.8
# Ragini           85  110  6.0
# Manali           89  111  7.5

# %% [markdown]
# # Maths Functions

# %%
# sum -- axis argument, mean, max, min, median, var

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Margin'].sum()
# Out:
# 15897.0

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.agg({'imdb_rating':['mean','sum','var','median','std']})
# Out:
#         imdb_rating
# mean       5.557459
# sum     9053.100000
# var        2.457397
# median     5.600000
# std        1.567609

# %% [markdown]
# # Selecting cols from a DataFrame

# %%
# selecting single column
ipl['City'].head(10)
# Out:
# 0      Ahmedabad
# 1      Ahmedabad
# 2        Kolkata
# 3        Kolkata
# 4         Mumbai
# 5         Mumbai
# 6         Mumbai
# 7         Mumbai
# 8    Navi Mumbai
# 9         Mumbai
# Name: City, dtype: object

# %%
movies[movies['genres'].str.split('|').apply(lambda genres: 'Action' in genres)]
# Out:
#                                title_x     imdb_id  \
# 0             Uri: The Surgical Strike   tt8291224
# 8     Manikarnika: The Queen of Jhansi   tt6903440
# 13                       Total Dhamaal   tt7639372
# 14                          Sonchiriya   tt8108200
# 16              Mard Ko Dard Nahi Hota   tt8055888
# ...                                ...         ...
# 1606   Hadh: Life on the Edge of Death   tt0396044
# 1607           Nayak (2001 Hindi film)   tt0291376
# 1608                        One 2 Ka 4   tt0227194
# 1617               Officer (2001 film)   tt0265452
# 1627                             Daaka  tt10833860
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 8     https://upload.wikimedia.org/wikipedia/en/thum...
# 13    https://upload.wikimedia.org/wikipedia/en/thum...
# 14    https://upload.wikimedia.org/wikipedia/en/thum...
# 16    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies[movies['genres'].str.split('|').apply(lambda genres: 'Drama' in genres)]
# Out:
#                                    title_x    imdb_id  \
# 0                 Uri: The Surgical Strike  tt8291224
# 2     The Accidental Prime Minister (film)  tt6986710
# 3                          Why Cheat India  tt8108208
# 4                          Evening Shadows  tt6028796
# 5                              Soni (film)  tt6078866
# ...                                    ...        ...
# 1623                              Zubeidaa  tt0255713
# 1624                 Tera Mera Saath Rahen  tt0301250
# 1625                  Yeh Zindagi Ka Safar  tt0298607
# 1626                       Sabse Bada Sukh  tt0069204
# 1628                              Humsafar  tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...

# %%
# selecting multiple columns

ipl[['Team1', 'Team2', 'WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# # Selecting rows from a DataFrame
#
# ## iloc - searches using index positions
# ## loc - searches using index labels

# %%
# single row
ipl.iloc[0]
# Out:
# ID                                                           1312200
# City                                                       Ahmedabad
# Date                                                      2022-05-29
# Season                                                          2022
# MatchNumber                                                    Final
# Team1                                               Rajasthan Royals
# Team2                                                 Gujarat Titans
# Venue                               Narendra Modi Stadium, Ahmedabad
# TossWinner                                          Rajasthan Royals
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                           Gujarat Titans
# WonBy                                                        Wickets
# Margin                                                           7.0
# ...

# %%
# multiple row
ipl.iloc[0:5]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# fancy indexing
ipl.iloc[[0,5,8]]
# Out:
#         ID         City        Date Season MatchNumber                 Team1  \
# 0  1312200    Ahmedabad  2022-05-29   2022       Final      Rajasthan Royals
# 5  1304115       Mumbai  2022-05-21   2022          69        Delhi Capitals
# 8  1304112  Navi Mumbai  2022-05-18   2022          66  Lucknow Super Giants
#
#                    Team2                               Venue  \
# 0         Gujarat Titans    Narendra Modi Stadium, Ahmedabad
# 5         Mumbai Indians            Wankhede Stadium, Mumbai
# 8  Kolkata Knight Riders  Dr DY Patil Sports Academy, Mumbai
#
#              TossWinner TossDecision SuperOver           WinningTeam    WonBy  \
# 0      Rajasthan Royals          bat         N        Gujarat Titans  Wickets
# 5        Mumbai Indians        field         N        Mumbai Indians  Wickets
# 8  Lucknow Super Giants          bat         N  Lucknow Super Giants     Runs
#
#    Margin method Player_of_Match  \
# 0     7.0    NaN       HH Pandya
# ...

# %%
# loc
ipl.loc[0:2,'Team1':'Team2']
# Out:
#                          Team1                 Team2
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants

# %%
students.loc['Biru':'Vipul']
# Out:
#          percentage   iq  CTC
# name
# Biru            100  100  8.0
# Anuj             85  120  9.0
# Shubham          95   63  4.0
# Miheer           56  125  5.0
# Vipul            78   78  7.8

# %%
students
# Out:
#          percentage   iq  CTC
# name
# Biru            100  100  8.0
# Anuj             85  120  9.0
# Shubham          95   63  4.0
# Miheer           56  125  5.0
# Vipul            78   78  7.8
# Ragini           85  110  6.0
# Manali           89  111  7.5

# %% [markdown]
# # Selecting both rows and cols

# %%
#
ipl.loc[10:20, 'Team1':'Team2']
# Out:
#                           Team1                        Team2
# 10               Delhi Capitals                 Punjab Kings
# 11             Rajasthan Royals         Lucknow Super Giants
# 12          Chennai Super Kings               Gujarat Titans
# 13        Kolkata Knight Riders          Sunrisers Hyderabad
# 14                 Punjab Kings  Royal Challengers Bangalore
# 15          Chennai Super Kings               Mumbai Indians
# 16             Rajasthan Royals               Delhi Capitals
# 17               Gujarat Titans         Lucknow Super Giants
# 18        Kolkata Knight Riders               Mumbai Indians
# 19          Chennai Super Kings               Delhi Capitals
# 20  Royal Challengers Bangalore          Sunrisers Hyderabad

# %% [markdown]
# # Filtering a DataFrame

# %%
# find all the final winners

final_winner = ipl[ipl['MatchNumber'] == 'Final']
final_winner[['Season', 'WinningTeam']]

# alternate method
ipl[ipl['MatchNumber']=='Final'][['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishes have occured
# ipl[ipl['SuperOver'] == 'Y'].count()
# ipl[ipl['SuperOver'] == 'Y'].shape[0]
len(ipl[ipl['SuperOver'] == 'Y'])
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# how many matches has csk won in kolkata
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
  # toss winner is match winner in percentage
len(ipl[ipl['TossWinner'] == ipl['WinningTeam']])/len(ipl['ID'])*100

# alterante method
ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0]*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 100000)]
# Out:
#                title_x    imdb_id  \
# 354      Dangal (film)  tt5074352
# 567          PK (film)  tt2338151
# 912           3 Idiots  tt1187043
# 1127  Taare Zameen Par  tt0986264
# 1195   Rang De Basanti  tt0405508
#
#                                             poster_path  \
# 354   https://upload.wikimedia.org/wikipedia/en/thum...
# 567   https://upload.wikimedia.org/wikipedia/en/thum...
# 912   https://upload.wikimedia.org/wikipedia/en/thum...
# 1127  https://upload.wikimedia.org/wikipedia/en/thum...
# 1195  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link              title_y  \
# 354      https://en.wikipedia.org/wiki/Dangal_(film)               Dangal
# 567          https://en.wikipedia.org/wiki/PK_(film)                   PK
# 912           https://en.wikipedia.org/wiki/3_Idiots             3 Idiots
# 1127  https://en.wikipedia.org/wiki/Taare_Zameen_Par  Like Stars on Earth
# ...

# %%
# Action movies with rating higher than 7.5
temp_df = movies[movies['genres'].str.split('|').apply(lambda genres : 'Action' in genres)]
temp_df[temp_df['imdb_rating'] > 7.5]

# Alteranate method
#mask1 = movies['genres'].str.contains('Actions')
#mask2 = movies['imdb_rating'] > 7.5

#movies[mask1 & mask2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
# write a function that can return the track record of 2 teams against each other
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # Adding new cols

# %%
# completely new

# %%
# from existing ones

# %% [markdown]
# # Important DataFrame Functions

# %%
# astype

# %%
# value_counts

# %%
# dropna

# %%
# fillna

# %%
# sort index

# %%
# reset index

# %%
# set index

# %%
# find which player has won most potm -> in finals and qualifiers

# %%
# Toss decision plot

# %%
# how many matches each team has played

# %%
# sort_values -> ascending -> na_position -> inplace -> multiple cols
